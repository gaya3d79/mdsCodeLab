# %% [markdown]
# <a href="https://colab.research.google.com/github/gaya3d79/mdsCodeLab/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("tester")
# Out:
# tester
